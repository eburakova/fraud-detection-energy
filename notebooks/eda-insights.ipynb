# %% [markdown]
# #### Account creation year
#
# ![Creation year and percent of fraud](../images/account_creation_years.png)
#
# #### Region
# Some regions are more prone to fraud than others: makes sense to converge the feature "region" to a simple binary flag (risk or no risk) or the probability (estimated by the share of committed fraud)
#
# ![Fraud by region](../images/percent%20of%20fraud%20by%20region%20dark.png)
#
# #### Mean counsumption rate at level 1
# Electricity (>100 invoices):
#
# ![image.png](attachment:image.png)
#
# Gas: (>20 invoices)
#
# ![image-2.png](attachment:image-2.png)
#
# Among clients with long history, those who commited fraud consumed much more.
#
# --> Feature engineering possibilities are vast! Should take mean consumption by month, standard deviation in consumption by month, etc.
# #### Tarif type
# If tarif type is 51, there is a bit higher chance of fraud
#
# ![image-3.png](attachment:image-3.png)
#
# ## Features EXCLUDED:
# * Counter code
# * Reading note
# * Client category
# * Counter statue
# * Counter type - already accounted for
